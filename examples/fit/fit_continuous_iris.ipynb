# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/phitter-hub/phitter-kernel/blob/main/examples/fit_continuous_iris.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys

import pandas

# %%
if os.getenv("COLAB_RELEASE_TAG"):
   # !pip install phitter --quiet
else:
   sys.path.append("../../")

# %%
import phitter

# %%
df = pandas.read_csv("https://gist.githubusercontent.com/phitter-hub/6e1cdb92a5f518c7459484c619185fc5/raw/4072c5233d03204d8999943398b23c2393bcd637/iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data = df["SepalWidthCm"].to_numpy()

# %%
phi = phitter.Phitter(data=data)
phi.fit(n_workers=2)

# %%
phi.best_distribution
# Out:
# {'id': 'gamma',
#  'parameters': {'alpha': 49.61019269899973, 'beta': 0.061559930204858414}}

# %%
phi.df_sorted_distributions
# Out:
#         distribution passed            aic            bic  \
#
# 0              gamma      ✅     175.466913     181.488184
# 1          lognormal      ✅     175.758136     181.779406
# 2   inverse_gaussian      ✅     175.801256     181.822527
# 3             erlang      ✅     175.917795     181.939065
# 4           nakagami      ✅     176.298530     182.319801
# ..               ...    ...            ...            ...
# 58    error_function     ✖️    7617.516680    7620.527316
# 59     inverse_gamma     ✖️   11190.673576   11196.694846
# 60                 f     ✖️   16954.378780   16960.400051
# 61            gibrat     ✖️   33654.804005   33660.825276
# 62          loggamma     ✖️  157502.820361  157511.852267
#
#                                   parameters     chi_square                 \
#                                              test_statistic critical_value
# 0                alpha: 49.61, beta: 0.06156   9.338464e+00      15.507313
# ...

# %%
phi.plot_histogram()

# %%
phi.plot_histogram_distributions()

# %%
phi.plot_distribution("burr_4p")

# %%
phi.plot_ecdf()

# %%
phi.plot_ecdf_distribution("logistic")

# %%
phi.qq_plot("logistic")

# %%
phi.qq_plot_regression("logistic")
